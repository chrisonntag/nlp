# %% [markdown]
# # Natural Language Processing
#
# ## Exercise Sheet 5

# %%
#imports for all exercises
import nltk
import re
import matplotlib.pyplot as plt
import nltk.book as book
from nltk.corpus import brown

brown_tags = [tag for (word, tag) in brown.tagged_words()]
brown_universal_tags = [tag for (word, tag) in brown.tagged_words(tagset='universal')]
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ### Exercise 1
#
# Produce a sorted list of tags used in the Brown corpus, removing duplicates. Do the same for the universal part-of-speech tagset.

# %%
list(sorted(set(brown_tags)))
# Out:
# ["'",
#  "''",
#  '(',
#  '(-HL',
#  ')',
#  ')-HL',
#  '*',
#  '*-HL',
#  '*-NC',
#  '*-TL',
#  ',',
#  ',-HL',
#  ',-NC',
#  ',-TL',
#  '--',
#  '---HL',
#  '.',
#  '.-HL',
#  '.-NC',
#  '.-TL',
#  ':',
#  ':-HL',
#  ':-TL',
#  'ABL',
#  'ABN',
#  'ABN-HL',
#  'ABN-NC',
#  'ABN-TL',
#  'ABX',
#  'AP',
#  'AP$',
#  'AP+AP-NC',
#  'AP-HL',
#  'AP-NC',
#  'AP-TL',
#  'AT',
#  'AT-HL',
#  'AT-NC',
#  'AT-TL',
#  'AT-TL-HL',
#  'BE',
#  'BE-HL',
#  'BE-TL',
#  'BED',
#  'BED*',
#  'BED-NC',
#  'BEDZ',
#  'BEDZ*',
#  'BEDZ-HL',
#  'BEDZ-NC',
#  'BEG',
#  'BEM',
#  'BEM*',
#  'BEM-NC',
#  'BEN',
#  'BEN-TL',
#  'BER',
#  'BER*',
#  'BER*-NC',
#  'BER-HL',
#  'BER-NC',
#  'BER-TL',
#  'BEZ',
#  'BEZ*',
#  'BEZ-HL',
#  'BEZ-NC',
#  'BEZ-TL',
#  'CC',
#  'CC-HL',
#  'CC-NC',
#  'CC-TL',
#  'CC-TL-HL',
#  'CD',
#  'CD$',
#  'CD-HL',
#  'CD-NC',
#  'CD-TL',
#  'CD-TL-HL',
#  'CS',
#  'CS-HL',
#  'CS-NC',
#  'CS-TL',
#  'DO',
#  'DO*',
#  'DO*-HL',
#  'DO+PPSS',
#  'DO-HL',
#  'DO-NC',
#  'DO-TL',
#  'DOD',
#  'DOD*',
#  'DOD*-TL',
#  'DOD-NC',
#  'DOZ',
#  'DOZ*',
#  'DOZ*-TL',
#  'DOZ-HL',
#  'DOZ-TL',
#  'DT',
#  'DT$',
#  'DT+BEZ',
#  'DT+BEZ-NC',
#  'DT+MD',
#  'DT-HL',
#  'DT-NC',
#  'DT-TL',
#  'DTI',
#  'DTI-HL',
#  'DTI-TL',
#  'DTS',
#  'DTS+BEZ',
#  'DTS-HL',
#  'DTX',
#  'EX',
#  'EX+BEZ',
#  'EX+HVD',
#  'EX+HVZ',
#  'EX+MD',
#  'EX-HL',
#  'EX-NC',
#  'FW-*',
#  'FW-*-TL',
#  'FW-AT',
#  'FW-AT+NN-TL',
#  'FW-AT+NP-TL',
#  'FW-AT-HL',
#  'FW-AT-TL',
#  'FW-BE',
#  'FW-BER',
#  'FW-BEZ',
#  'FW-CC',
#  'FW-CC-TL',
#  'FW-CD',
#  'FW-CD-TL',
#  'FW-CS',
#  'FW-DT',
#  'FW-DT+BEZ',
#  'FW-DTS',
#  'FW-HV',
#  'FW-IN',
#  'FW-IN+AT',
#  'FW-IN+AT-T',
#  'FW-IN+AT-TL',
#  'FW-IN+NN',
#  'FW-IN+NN-TL',
#  'FW-IN+NP-TL',
#  'FW-IN-TL',
#  'FW-JJ',
#  'FW-JJ-NC',
#  'FW-JJ-TL',
#  'FW-JJR',
#  'FW-JJT',
#  'FW-NN',
#  'FW-NN$',
#  'FW-NN$-TL',
#  'FW-NN-NC',
#  'FW-NN-TL',
#  'FW-NN-TL-NC',
#  'FW-NNS',
#  'FW-NNS-NC',
#  'FW-NNS-TL',
#  'FW-NP',
#  'FW-NP-TL',
#  'FW-NPS',
#  'FW-NPS-TL',
#  'FW-NR',
#  'FW-NR-TL',
#  'FW-OD-NC',
#  'FW-OD-TL',
#  'FW-PN',
#  'FW-PP$',
#  'FW-PP$-NC',
#  'FW-PP$-TL',
#  'FW-PPL',
#  'FW-PPL+VBZ',
#  'FW-PPO',
#  'FW-PPO+IN',
#  'FW-PPS',
#  'FW-PPSS',
#  'FW-PPSS+HV',
#  'FW-QL',
#  'FW-RB',
#  'FW-RB+CC',
#  'FW-RB-TL',
#  'FW-TO+VB',
#  'FW-UH',
#  'FW-UH-NC',
#  'FW-UH-TL',
#  'FW-VB',
#  'FW-VB-NC',
#  'FW-VB-TL',
#  'FW-VBD',
#  'FW-VBD-TL',
#  'FW-VBG',
#  'FW-VBG-TL',
#  'FW-VBN',
#  'FW-VBZ',
#  'FW-WDT',
#  'FW-WPO',
#  'FW-WPS',
#  'HV',
#  'HV*',
#  'HV+TO',
#  'HV-HL',
#  'HV-NC',
#  'HV-TL',
#  'HVD',
#  'HVD*',
#  'HVD-HL',
#  'HVG',
#  'HVG-HL',
#  'HVN',
#  'HVZ',
#  'HVZ*',
#  'HVZ-NC',
#  'HVZ-TL',
#  'IN',
#  'IN+IN',
#  'IN+PPO',
#  'IN-HL',
#  'IN-NC',
#  'IN-TL',
#  'IN-TL-HL',
#  'JJ',
#  'JJ$-TL',
#  'JJ+JJ-NC',
#  'JJ-HL',
#  'JJ-NC',
#  'JJ-TL',
#  'JJ-TL-HL',
#  'JJ-TL-NC',
#  'JJR',
#  'JJR+CS',
#  'JJR-HL',
#  'JJR-NC',
#  'JJR-TL',
#  'JJS',
#  'JJS-HL',
#  'JJS-TL',
#  'JJT',
#  'JJT-HL',
#  'JJT-NC',
#  'JJT-TL',
#  'MD',
#  'MD*',
#  'MD*-HL',
#  'MD+HV',
#  'MD+PPSS',
#  'MD+TO',
#  'MD-HL',
#  'MD-NC',
#  'MD-TL',
#  'NIL',
#  'NN',
#  'NN$',
#  'NN$-HL',
#  'NN$-TL',
#  'NN+BEZ',
#  'NN+BEZ-TL',
#  'NN+HVD-TL',
#  'NN+HVZ',
#  'NN+HVZ-TL',
#  'NN+IN',
#  'NN+MD',
#  'NN+NN-NC',
#  'NN-HL',
#  'NN-NC',
#  'NN-TL',
#  'NN-TL-HL',
#  'NN-TL-NC',
#  'NNS',
#  'NNS$',
#  'NNS$-HL',
#  'NNS$-NC',
#  'NNS$-TL',
#  'NNS$-TL-HL',
#  'NNS+MD',
#  'NNS-HL',
#  'NNS-NC',
#  'NNS-TL',
#  'NNS-TL-HL',
#  'NNS-TL-NC',
#  'NP',
#  'NP$',
#  'NP$-HL',
#  'NP$-TL',
#  'NP+BEZ',
#  'NP+BEZ-NC',
#  'NP+HVZ',
#  'NP+HVZ-NC',
#  'NP+MD',
#  'NP-HL',
#  'NP-NC',
#  'NP-TL',
#  'NP-TL-HL',
#  'NPS',
#  'NPS$',
#  'NPS$-HL',
#  'NPS$-TL',
#  'NPS-HL',
#  'NPS-NC',
#  'NPS-TL',
#  'NR',
#  'NR$',
#  'NR$-TL',
#  'NR+MD',
#  'NR-HL',
#  'NR-NC',
#  'NR-TL',
#  'NR-TL-HL',
#  'NRS',
#  'NRS-TL',
#  'OD',
#  'OD-HL',
#  'OD-NC',
#  'OD-TL',
#  'PN',
#  'PN$',
#  'PN+BEZ',
#  'PN+HVD',
#  'PN+HVZ',
#  'PN+MD',
#  'PN-HL',
#  'PN-NC',
#  'PN-TL',
#  'PP$',
#  'PP$$',
#  'PP$-HL',
#  'PP$-NC',
#  'PP$-TL',
#  'PPL',
#  'PPL-HL',
#  'PPL-NC',
#  'PPL-TL',
#  'PPLS',
#  'PPO',
#  'PPO-HL',
#  'PPO-NC',
#  'PPO-TL',
#  'PPS',
#  'PPS+BEZ',
#  'PPS+BEZ-HL',
#  'PPS+BEZ-NC',
#  'PPS+HVD',
#  'PPS+HVZ',
#  'PPS+MD',
#  'PPS-HL',
#  'PPS-NC',
#  'PPS-TL',
#  'PPSS',
#  'PPSS+BEM',
#  'PPSS+BER',
#  'PPSS+BER-N',
#  'PPSS+BER-NC',
#  'PPSS+BER-TL',
#  'PPSS+BEZ',
#  'PPSS+BEZ*',
#  'PPSS+HV',
#  'PPSS+HV-TL',
#  'PPSS+HVD',
#  'PPSS+MD',
#  'PPSS+MD-NC',
#  'PPSS+VB',
#  'PPSS-HL',
#  'PPSS-NC',
#  'PPSS-TL',
#  'QL',
#  'QL-HL',
#  'QL-NC',
#  'QL-TL',
#  'QLP',
#  'RB',
#  'RB$',
#  'RB+BEZ',
#  'RB+BEZ-HL',
#  'RB+BEZ-NC',
#  'RB+CS',
#  'RB-HL',
#  'RB-NC',
#  'RB-TL',
#  'RBR',
#  'RBR+CS',
#  'RBR-NC',
#  'RBT',
#  'RN',
#  'RP',
#  'RP+IN',
#  'RP-HL',
#  'RP-NC',
#  'RP-TL',
#  'TO',
#  'TO+VB',
#  'TO-HL',
#  'TO-NC',
#  'TO-TL',
#  'UH',
#  'UH-HL',
#  'UH-NC',
#  'UH-TL',
#  'VB',
#  'VB+AT',
#  'VB+IN',
#  'VB+JJ-NC',
#  'VB+PPO',
#  'VB+RP',
#  'VB+TO',
#  'VB+VB-NC',
#  'VB-HL',
#  'VB-NC',
#  'VB-TL',
#  'VBD',
#  'VBD-HL',
#  'VBD-NC',
#  'VBD-TL',
#  'VBG',
#  'VBG+TO',
#  'VBG-HL',
#  'VBG-NC',
#  'VBG-TL',
#  'VBN',
#  'VBN+TO',
#  'VBN-HL',
#  'VBN-NC',
#  'VBN-TL',
#  'VBN-TL-HL',
#  'VBN-TL-NC',
#  'VBZ',
#  'VBZ-HL',
#  'VBZ-NC',
#  'VBZ-TL',
#  'WDT',
#  'WDT+BER',
#  'WDT+BER+PP',
#  'WDT+BEZ',
#  'WDT+BEZ-HL',
#  'WDT+BEZ-NC',
#  'WDT+BEZ-TL',
#  'WDT+DO+PPS',
#  'WDT+DOD',
#  'WDT+HVZ',
#  'WDT-HL',
#  'WDT-NC',
#  'WP$',
#  'WPO',
#  'WPO-NC',
#  'WPO-TL',
#  'WPS',
#  'WPS+BEZ',
#  'WPS+BEZ-NC',
#  'WPS+BEZ-TL',
#  'WPS+HVD',
#  'WPS+HVZ',
#  'WPS+MD',
#  'WPS-HL',
#  'WPS-NC',
#  'WPS-TL',
#  'WQL',
#  'WQL-TL',
#  'WRB',
#  'WRB+BER',
#  'WRB+BEZ',
#  'WRB+BEZ-TL',
#  'WRB+DO',
#  'WRB+DOD',
#  'WRB+DOD*',
#  'WRB+DOZ',
#  'WRB+IN',
#  'WRB+MD',
#  'WRB-HL',
#  'WRB-NC',
#  'WRB-TL',
#  '``']

# %%
list(sorted(set(brown_universal_tags)))
# Out:
# ['.',
#  'ADJ',
#  'ADP',
#  'ADV',
#  'CONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PRON',
#  'PRT',
#  'VERB',
#  'X']

# %% [markdown]
# ### Exercise 2
#
# Write a program to process the Brown Corpus using the universal part-of-speech tagset to find out which nouns are more common in their plural form than in their singular form. Only consider regular plurals formed with the "-s" suffix. Print an alphabetically sorted list of the nouns together with the frequencies for the singular and plural forms, one per line.

# %%
# Normalize nouns, so that report and Report is the same word
nouns = [word.lower() for (word, tag) in brown.tagged_words(tagset='universal') if tag == "NOUN"]

# only compare nouns that are words
reg = re.compile(r'^[a-z]')
nouns = list(filter(reg.search, nouns))

noun_fd = nltk.FreqDist(nouns)

# %%
# Select only singular nouns, excluding regular formed plurals with the -s suffix
singular_nouns = [singular_noun for singular_noun in nouns if singular_noun[-1:] != "s"]

common_dict = dict()
# Search each singular word once and compare frequency distributions
for noun in set(singular_nouns):
    singular_freq = noun_fd[noun]
    plural_freq = noun_fd[noun + "s"]
    
    if plural_freq > singular_freq:
        common_dict[noun] = (singular_freq, plural_freq)

# %%
print("Noun: singular, plural")
print("===")
for noun in sorted(common_dict.keys()):
    print("{}: {}, {}".format(noun, common_dict[noun][0], common_dict[noun][1]))
# Out:
# Noun: singular, plural
# ===
# aberration: 3, 5
# abolitionist: 1, 4
# aborigine: 7, 8
# absolute: 1, 3
# abstract: 1, 4
# accommodation: 1, 8
# accomplishment: 7, 10
# acre: 10, 44
# active: 6, 8
# ad: 5, 10
# adapter: 1, 2
# addict: 1, 4
# additive: 3, 4
# adherent: 1, 5
# adjective: 2, 4
# admonition: 1, 3
# adventure: 13, 14
# adverb: 1, 2
# advertisement: 2, 3
# advertiser: 1, 5
# adviser: 6, 12
# advisor: 1, 5
# affair: 33, 84
# affiliation: 4, 5
# ailment: 4, 6
# airfield: 5, 6
# airline: 2, 5
# alien: 2, 3
# allowance: 16, 25
# allusion: 3, 5
# almond: 1, 3
# american: 34, 93
# angel: 18, 24
# ant: 6, 7
# antagonist: 3, 4
# antecedent: 1, 2
# anti-semite: 2, 3
# apache: 1, 4
# apologie: 1, 4
# appliance: 5, 8
# applicant: 8, 10
# appointee: 2, 5
# appropriation: 5, 9
# arm: 93, 121
# armament: 1, 4
# arrangement: 34, 38
# aspect: 47, 64
# aspencade: 1, 2
# aspiration: 3, 12
# assessor: 2, 20
# asset: 5, 13
# associate: 7, 14
# atom: 37, 40
# attribute: 4, 11
# auditor: 1, 4
# authorization: 2, 6
# axe: 6, 7
# axiom: 1, 2
# azalea: 2, 3
# backbend: 1, 2
# backyard: 2, 3
# bang: 3, 5
# banker: 5, 15
# banshee: 1, 2
# barbarian: 1, 4
# barrack: 1, 3
# barricade: 2, 4
# barrier: 9, 17
# bastard: 12, 14
# batten: 3, 15
# batterie: 1, 3
# bead: 1, 4
# bean: 5, 9
# bearden: 4, 5
# bee: 11, 15
# being: 30, 36
# believer: 4, 5
# bellow: 4, 7
# belonging: 1, 4
# bicep: 1, 3
# bidder: 2, 3
# billboard: 1, 2
# binder: 1, 2
# bird: 31, 57
# biscuit: 2, 5
# bite: 3, 6
# blossom: 4, 7
# blue: 17, 22
# blueprint: 1, 2
# bomb: 33, 35
# bomber: 8, 22
# bond: 46, 47
# booklet: 1, 2
# boot: 10, 20
# bootlegger: 1, 2
# bough: 2, 4
# bound: 3, 10
# bracket: 1, 2
# brake: 2, 7
# brave: 1, 3
# bristle: 2, 3
# broker: 1, 4
# bronchiole: 4, 9
# brook: 3, 16
# brothel: 1, 2
# bruise: 2, 8
# bubble: 12, 13
# buddhist: 1, 2
# bug: 4, 7
# bumblebee: 2, 10
# bun: 1, 8
# burglar: 1, 2
# burn: 5, 21
# bushel: 1, 4
# buyer: 2, 5
# byproduct: 2, 3
# caller: 2, 3
# calorie: 1, 7
# camper: 3, 9
# canadian: 1, 2
# candidate: 34, 38
# canon: 5, 6
# card: 26, 36
# carrier: 9, 11
# carrot: 1, 4
# cart: 4, 5
# cartoon: 3, 6
# catholic: 1, 33
# catkin: 2, 5
# cell: 65, 81
# centimeter: 2, 8
# channel: 15, 23
# chant: 1, 3
# characteristic: 24, 52
# cheekbone: 1, 5
# cheyenne: 2, 3
# chop: 2, 3
# chore: 7, 16
# christian: 13, 17
# chunk: 2, 5
# circumstance: 15, 84
# citizen: 30, 86
# classic: 5, 9
# classmate: 3, 4
# claw: 1, 3
# cleaner: 5, 8
# clement: 1, 3
# clod: 1, 4
# cloud: 28, 37
# clove: 1, 2
# collaborator: 1, 4
# colleague: 9, 23
# commercial: 2, 10
# commitment: 13, 15
# commune: 3, 5
# competitor: 3, 10
# complication: 4, 5
# compliment: 3, 4
# component: 25, 55
# compound: 9, 15
# comrade: 4, 10
# concentrate: 1, 5
# concession: 3, 7
# concessionaire: 2, 7
# condition: 90, 180
# confederate: 1, 2
# conformist: 2, 3
# congratulation: 1, 7
# congregationalist: 2, 3
# conjugate: 10, 14
# conqueror: 1, 2
# consequence: 30, 35
# conservative: 3, 4
# consonant: 2, 4
# constituent: 5, 10
# contour: 6, 15
# contributor: 2, 6
# convert: 3, 5
# cookie: 3, 6
# cooperative: 1, 10
# coordinate: 2, 5
# cop: 15, 17
# corp: 1, 103
# cosmetic: 1, 7
# cosmo: 1, 3
# cossack: 3, 4
# costume: 10, 18
# counterpart: 9, 11
# cowbird: 1, 3
# crackpot: 1, 2
# crater: 2, 5
# creature: 15, 20
# creeper: 1, 2
# critic: 25, 26
# critter: 1, 3
# crusader: 1, 2
# crystallite: 1, 3
# cube: 1, 4
# cuff: 1, 2
# custom: 10, 18
# customer: 27, 40
# cutter: 4, 6
# dam: 2, 3
# dane: 2, 4
# dealer: 25, 30
# decree: 3, 4
# defect: 3, 13
# defendant: 6, 10
# defender: 3, 6
# delegate: 4, 16
# deliberation: 2, 7
# deltoid: 1, 2
# democrat: 13, 40
# denomination: 8, 15
# dependent: 1, 2
# descendant: 2, 4
# destroyer: 2, 3
# determinant: 1, 2
# dimension: 14, 30
# diplomat: 5, 6
# directive: 2, 4
# disadvantage: 4, 9
# disc: 6, 7
# disciple: 4, 5
# disclosure: 2, 4
# dislocation: 1, 2
# ditmar: 1, 2
# diver: 1, 2
# dividend: 6, 8
# document: 11, 19
# dodger: 1, 5
# doing: 4, 6
# doll: 10, 12
# dollar: 46, 97
# dolphin: 1, 4
# dose: 11, 13
# down: 2, 5
# dragon: 1, 2
# drawing: 12, 21
# dresser: 1, 2
# drier: 1, 3
# drug: 24, 28
# drum: 11, 15
# duck: 2, 4
# duct: 1, 6
# duffer: 1, 2
# dune: 1, 8
# dynamic: 1, 4
# dystopia: 2, 8
# eagle: 5, 6
# ear: 29, 38
# eccentric: 1, 2
# eclipse: 2, 4
# egg: 12, 35
# elder: 6, 9
# elector: 2, 3
# element: 52, 107
# elephant: 7, 10
# ellipsoid: 1, 4
# emerald: 3, 6
# emotion: 34, 43
# employe: 1, 17
# employee: 24, 66
# employer: 15, 17
# endearment: 1, 2
# endowment: 2, 4
# entertainer: 2, 3
# enthusiast: 2, 3
# enzyme: 6, 11
# epicycle: 1, 6
# epithet: 2, 7
# error: 36, 44
# escapade: 1, 2
# ethic: 4, 19
# european: 2, 5
# event: 81, 101
# evocation: 1, 2
# expectation: 11, 23
# expenditure: 11, 44
# experiment: 56, 66
# expert: 19, 38
# exploit: 1, 4
# explosive: 1, 3
# export: 8, 11
# extract: 1, 3
# eye: 122, 401
# eyebrow: 4, 9
# eyelid: 1, 7
# fabric: 15, 29
# facet: 2, 9
# faction: 5, 6
# factor: 71, 105
# fan: 14, 19
# farmer: 23, 33
# fat: 13, 19
# favorite: 4, 12
# feather: 5, 14
# feature: 30, 75
# fee: 16, 29
# felon: 1, 2
# ferraro: 2, 3
# feud: 1, 2
# fighter: 9, 16
# filbert: 1, 2
# fill-in: 1, 2
# fin: 2, 5
# final: 1, 10
# finding: 11, 34
# finger: 40, 66
# firecracker: 1, 2
# flame: 13, 14
# flare: 3, 5
# flower: 22, 57
# follower: 3, 17
# footstep: 3, 8
# forecast: 3, 5
# foreigner: 4, 13
# fragment: 6, 10
# franc: 1, 3
# freeholder: 1, 3
# friend: 133, 161
# fund: 62, 95
# furnishing: 3, 9
# ga: 1, 98
# gable: 2, 4
# gadget: 4, 7
# gangster: 2, 4
# gasp: 2, 5
# generalist: 1, 2
# generalization: 4, 7
# geologist: 2, 3
# ghoul: 1, 2
# giant: 6, 21
# giggle: 1, 4
# golfer: 3, 4
# gram: 10, 18
# grape: 3, 7
# grassland: 1, 6
# greeting: 4, 6
# grenade: 3, 6
# grit: 1, 3
# grocer: 1, 3
# groove: 2, 3
# grower: 1, 3
# guerrilla: 12, 17
# guest: 39, 62
# gunner: 1, 2
# gust: 1, 3
# gut: 1, 9
# gutter: 1, 2
# gymnast: 1, 4
# gynecologist: 1, 2
# han: 9, 44
# handstand: 1, 3
# happening: 2, 5
# harper: 2, 3
# harris': 1, 2
# headache: 5, 6
# headline: 4, 7
# headquarter: 1, 65
# heel: 9, 23
# helmet: 1, 2
# hercule: 1, 3
# heron: 1, 2
# herpetologist: 1, 2
# highland: 1, 6
# highlight: 2, 3
# hike: 3, 4
# hinge: 1, 3
# hit: 12, 15
# hitter: 2, 4
# honeybee: 2, 4
# hoof: 2, 7
# hostage: 2, 3
# hour: 145, 174
# hue: 1, 2
# hulk: 2, 3
# hydride: 2, 3
# ideal: 15, 16
# ill: 1, 9
# immigrant: 4, 10
# imperfection: 1, 2
# implement: 1, 5
# implication: 10, 22
# improvisation: 1, 2
# indian: 10, 32
# indicator: 8, 9
# infestation: 2, 4
# inflection: 3, 4
# ingredient: 6, 9
# injunction: 3, 5
# inmate: 1, 6
# insect: 14, 23
# insecticide: 1, 2
# insinuation: 2, 3
# installation: 12, 16
# institution: 41, 98
# instruction: 26, 35
# intellectual: 9, 12
# interface: 3, 5
# interrelationship: 1, 2
# interval: 18, 25
# invader: 1, 5
# investigator: 4, 13
# investor: 2, 16
# ion: 6, 9
# italian: 4, 7
# item: 55, 72
# jacob: 1, 2
# james': 1, 2
# jaycee: 1, 3
# jerebohm: 2, 3
# jew: 26, 54
# jewel: 1, 3
# jowl: 2, 4
# junior: 17, 31
# jurist: 3, 4
# kenning: 1, 10
# keynote: 1, 2
# knee: 35, 38
# knuckle: 2, 7
# kroger: 2, 3
# lag: 1, 2
# lament: 1, 2
# lamentation: 1, 2
# landmark: 3, 7
# lao: 17, 64
# lapel: 1, 2
# leader: 74, 107
# leaflet: 1, 3
# leak: 2, 3
# leave: 10, 23
# lecture: 14, 15
# leg: 58, 67
# legislator: 7, 20
# len: 3, 12
# lewis': 1, 5
# liberal: 12, 26
# libertie: 1, 8
# libertine: 1, 2
# librarian: 5, 6
# ligand: 1, 2
# limit: 31, 37
# limitation: 10, 28
# lip: 18, 69
# listener: 10, 20
# litigant: 2, 3
# lo: 21, 51
# lobe: 3, 5
# lobule: 1, 2
# locale: 3, 4
# lodging: 1, 2
# loin: 1, 2
# longhorn: 4, 5
# loudspeaker: 1, 2
# louis': 1, 2
# lung: 16, 20
# lyric: 7, 15
# magpie: 1, 2
# make: 3, 4
# maker: 12, 19
# mammal: 1, 3
# mana: 3, 4
# maneuver: 3, 8
# manifestation: 6, 9
# manual: 2, 4
# manufacturer: 23, 47
# map: 12, 13
# mar: 2, 19
# marking: 1, 2
# mean: 12, 205
# measurement: 34, 54
# mechanic: 5, 19
# meditation: 2, 4
# megaton: 2, 10
# member: 137, 325
# memoir: 2, 4
# merchant: 20, 22
# metaphysic: 3, 12
# meteor: 3, 4
# meteorite: 6, 8
# meter: 6, 11
# mexican: 5, 12
# microorganism: 1, 12
# mile: 48, 173
# mill: 11, 32
# milligram: 5, 21
# mine: 21, 28
# miner: 1, 5
# mineral: 12, 14
# minute: 44, 196
# moccasin: 1, 2
# modification: 4, 6
# molecule: 6, 9
# monosyllable: 1, 2
# month: 130, 189
# moral: 5, 7
# mose: 6, 9
# moth: 1, 2
# motorist: 2, 5
# mountain: 33, 43
# movie: 29, 31
# mug: 1, 2
# musician: 23, 41
# mystic: 1, 3
# nail: 6, 14
# narcotic: 1, 7
# nation: 139, 175
# national: 3, 4
# native: 10, 11
# negotiation: 6, 20
# neighbor: 14, 40
# nerve: 12, 22
# newlywed: 1, 2
# nightclub: 2, 4
# nikolai: 2, 4
# nomia: 1, 2
# norm: 10, 24
# northerner: 4, 5
# nostril: 1, 3
# noun: 1, 3
# nuance: 1, 3
# nun: 2, 4
# nut: 15, 20
# object: 53, 62
# obligation: 16, 21
# observation: 27, 40
# observer: 16, 20
# occupant: 4, 9
# official: 20, 62
# oilseed: 1, 4
# orchard: 3, 5
# organ: 12, 14
# organism: 6, 7
# oriole: 5, 11
# outbreak: 2, 3
# outburst: 2, 6
# outsider: 3, 8
# overall: 2, 5
# overhang: 1, 2
# owner: 33, 35
# oyster: 6, 8
# pacer: 1, 3
# painting: 27, 36
# pajama: 1, 3
# pamphlet: 2, 9
# panel: 31, 46
# paragraph: 12, 14
# parameter: 7, 8
# parasite: 1, 4
# parent: 15, 91
# parson: 2, 5
# participant: 4, 7
# particle: 21, 42
# passenger: 14, 21
# patron: 4, 9
# paw: 2, 3
# peacock: 2, 4
# peasant: 7, 12
# pebble: 1, 3
# peer: 6, 7
# peptide: 1, 2
# performer: 7, 13
# periodical: 4, 5
# persian: 1, 12
# personage: 1, 3
# perturbation: 1, 2
# pheasant: 1, 2
# phillip: 2, 11
# photo: 5, 7
# photographer: 5, 6
# picker: 1, 3
# pier: 3, 6
# pilgrim: 4, 6
# pillar: 2, 5
# pink: 1, 2
# pirate: 4, 12
# plain: 7, 14
# planet: 21, 22
# planner: 2, 13
# plaque: 2, 4
# plastic: 25, 31
# plate: 22, 23
# poem: 48, 82
# politician: 13, 19
# poll: 9, 10
# polymer: 1, 4
# polyphosphate: 1, 5
# pop: 4, 10
# pore: 2, 3
# potter: 4, 8
# pound: 26, 44
# practitioner: 2, 6
# precept: 1, 3
# predecessor: 5, 6
# predisposition: 4, 9
# premise: 7, 8
# prerogative: 1, 2
# preserve: 4, 8
# prisoner: 7, 21
# probe: 1, 3
# proceeding: 5, 18
# product: 87, 108
# professional: 6, 10
# progression: 2, 3
# projection: 9, 10
# promoter: 1, 4
# prop: 2, 6
# propagandist: 3, 4
# proponent: 2, 6
# protease: 1, 4
# protestant: 3, 14
# psychiatrist: 4, 5
# psychologist: 10, 11
# publisher: 9, 11
# puddle: 1, 2
# pupil: 20, 25
# purge: 1, 2
# push-up: 3, 4
# qualification: 8, 16
# quotation: 4, 5
# race-driver: 3, 4
# racketeer: 2, 3
# ramification: 1, 3
# rating: 6, 9
# rattlesnake: 3, 5
# rdw: 2, 4
# reagent: 1, 3
# realtor: 5, 19
# reb: 2, 5
# rebel: 15, 16
# receipt: 4, 7
# recrimination: 1, 3
# recruit: 1, 8
# redcoat: 6, 9
# referral: 6, 8
# regulation: 14, 29
# rein: 3, 9
# reinforcement: 2, 3
# relation: 63, 102
# relative: 1, 22
# remark: 29, 46
# rendition: 1, 3
# reporter: 20, 34
# representative: 29, 41
# repulsion: 1, 2
# requirement: 27, 83
# researcher: 3, 4
# reservation: 8, 9
# resident: 8, 20
# resistor: 3, 7
# resource: 9, 72
# restriction: 8, 27
# resultant: 1, 5
# retailer: 1, 5
# revision: 8, 9
# rib: 1, 11
# riddle: 1, 2
# rim-fire: 2, 3
# ripple: 4, 5
# robber: 2, 6
# robot: 1, 3
# rocket: 7, 13
# rogue: 1, 2
# romantic: 1, 5
# roommate: 1, 2
# rule: 66, 82
# ruler: 3, 9
# runner: 1, 5
# rupee: 6, 14
# russian: 11, 31
# rut: 1, 2
# sacrament: 1, 2
# sailboat: 1, 3
# sailor: 5, 8
# sale: 44, 133
# salon: 1, 3
# sausage: 1, 5
# savage: 3, 6
# saving: 3, 23
# scholar: 15, 27
# schoolmate: 1, 2
# scientist: 17, 36
# scot: 1, 8
# scripture: 4, 11
# secant: 12, 16
# sedan: 2, 4
# sediment: 3, 4
# seed: 40, 42
# seeker: 1, 3
# sensor: 3, 6
# serpent: 2, 3
# servant: 19, 22
# settler: 3, 12
# shaker: 2, 3
# shareholder: 1, 3
# shipment: 2, 16
# shoe: 14, 44
# short: 3, 29
# shortcut: 1, 2
# shred: 1, 5
# shrub: 1, 4
# shunt: 1, 5
# si: 1, 3
# silhouette: 4, 5
# silo: 1, 2
# singer: 10, 13
# siren: 1, 2
# skipper: 1, 2
# skylight: 1, 2
# slack: 3, 7
# slave: 30, 44
# slipper: 3, 7
# sneaker: 2, 3
# sock: 3, 7
# soldier: 39, 56
# sole: 2, 5
# solid: 7, 13
# somersault: 2, 3
# soothsayer: 1, 2
# southerner: 8, 26
# soybean: 5, 6
# spacer: 2, 5
# specialist: 16, 19
# specification: 3, 9
# spectator: 9, 13
# speculation: 3, 4
# speculator: 1, 2
# spice: 2, 3
# spike: 1, 3
# spoke: 1, 2
# sport: 17, 48
# spouse: 3, 4
# stain: 4, 9
# stair: 2, 47
# stamp: 3, 4
# standard: 31, 74
# star: 25, 29
# step: 110, 118
# steroid: 1, 2
# stockholder: 2, 26
# strap: 1, 2
# stray: 1, 6
# stripe: 4, 5
# striving: 1, 3
# student: 131, 213
# stump: 2, 5
# submarine: 15, 20
# subordinate: 1, 9
# subsystem: 2, 10
# suburb: 13, 18
# suitor: 1, 3
# sultan: 3, 4
# superior: 1, 4
# supermarket: 1, 3
# supporter: 3, 8
# surfactant: 1, 2
# survivalist: 1, 2
# survivor: 1, 13
# swell: 1, 4
# swelling: 1, 2
# syllable: 1, 9
# symptom: 5, 14
# tablespoon: 6, 7
# tactic: 4, 20
# tangent: 4, 6
# tank: 12, 18
# tanker: 1, 2
# tara: 1, 3
# tavern: 2, 4
# taxpayer: 11, 21
# teamster: 1, 8
# tear: 2, 34
# technician: 6, 12
# technique: 60, 99
# teen-ager: 2, 12
# teenager: 2, 5
# tektite: 1, 5
# telegrapher: 3, 5
# tenant: 5, 9
# tenement: 2, 3
# tentacle: 1, 2
# term: 76, 160
# terminal: 3, 4
# texan: 4, 9
# theologian: 5, 9
# thicket: 1, 2
# thing: 333, 368
# third: 2, 4
# thug: 1, 2
# tick: 1, 2
# tidbit: 1, 2
# toe: 7, 19
# ton: 13, 28
# tonic: 1, 2
# topic: 9, 10
# towel: 6, 11
# toy: 4, 10
# trader: 8, 26
# trailer: 11, 12
# trait: 3, 6
# traitor: 2, 4
# tranquilizer: 1, 4
# transformer: 1, 2
# treasure: 4, 6
# tree: 59, 101
# tribe: 4, 12
# trimming: 1, 4
# triplet: 1, 3
# troop: 16, 53
# trouser: 3, 7
# trustee: 9, 25
# twin: 6, 12
# undergraduate: 4, 9
# underwriter: 1, 4
# uprising: 1, 2
# user: 4, 6
# utopian: 2, 5
# valve: 3, 4
# variable: 11, 26
# vase: 4, 11
# vault: 2, 6
# vegetable: 10, 16
# vehicle: 35, 53
# vendor: 1, 2
# verb: 4, 7
# villain: 3, 4
# vine: 4, 8
# vineyard: 2, 5
# visitor: 13, 36
# vitamin: 5, 10
# volunteer: 5, 29
# voter: 4, 20
# vow: 2, 4
# wandering: 1, 3
# warrior: 5, 7
# watershed: 3, 4
# waterway: 2, 3
# wave: 44, 51
# wavelength: 4, 6
# weapon: 42, 61
# weave: 1, 2
# williams': 1, 2
# win: 1, 3
# wing: 17, 27
# worker: 30, 86
# worm: 4, 5
# wrinkle: 2, 7
# yankee: 10, 28
# yard: 35, 64
# year: 656, 949
# youngster: 8, 18

# %% [markdown]
# ### Exercise 3
#
# Find out which word has the greatest number of distinct tags in the Brown corpus using the original tagset. Without using the `most_common` function, print a list of the tags together with the frequencies for the word, sorted by frequency from highest to lowest, one per line.

# %%
tagged_words = brown.tagged_words()

word_tags = dict()
for word, tag in tagged_words:
    if word not in word_tags.keys():
        word_tags[word] = {tag}
    else:
        word_tags[word].add(tag)

# %%
word_tags_sorted = sorted(word_tags.items(), key=lambda item: len(item[1]), reverse=True)
most_distinct_tags_word = word_tags_sorted[0]
most_distinct_tags_word
# Out:
# ('that',
#  {'CS',
#   'CS-HL',
#   'CS-NC',
#   'DT',
#   'DT-NC',
#   'NIL',
#   'QL',
#   'WPO',
#   'WPO-NC',
#   'WPS',
#   'WPS-HL',
#   'WPS-NC'})

# %% [markdown]
# The word with the greatest number of distinct tags in the Brown corpus is: ```that```

# %%
# Print a list of the tags of the word with the greatest number of distinct tags, sorted by frequency
tags_fd = nltk.FreqDist(tagged_words) 

most_distinct_tags_word_freq = sorted({tag: tags_fd[(most_distinct_tags_word[0], tag)] for tag in most_distinct_tags_word[1]}.items(), key=lambda item: item[1], reverse=True)

for tag, freq in most_distinct_tags_word_freq:
    print(tag, freq)
# Out:
# CS 6419
# DT 1975
# WPS 1638
# WPO 135
# QL 54
# DT-NC 6
# WPS-NC 3
# WPS-HL 2
# CS-NC 2
# NIL 1
# CS-HL 1
# WPO-NC 1

# %%
nltk.help.upenn_tagset('CS')
nltk.corpus.brown.readme()
# Out:
# No matching tags found.
# 'BROWN CORPUS\n\nA Standard Corpus of Present-Day Edited American\nEnglish, for use with Digital Computers.\n\nby W. N. Francis and H. Kucera (1964)\nDepartment of Linguistics, Brown University\nProvidence, Rhode Island, USA\n\nRevised 1971, Revised and Amplified 1979\n\nhttp://www.hit.uib.no/icame/brown/bcm.html\n\nDistributed with the permission of the copyright holder,\nredistribution permitted.\n'

# %%
# Print a list of the tags for each word, sorted by frequency
"""
words_fd = nltk.FreqDist(brown.words())

for word, freq in sorted(words_fd.items(), key=lambda item: item[1], reverse=True):
    print("{}({}): ".format(word, freq), word_tags[word])
"""

# %% [markdown]
# ### Exercise 4
#
# Tabulate the frequencies of the universal tags that precede nouns in the Brown Corpus.

# %%
word_tag_pairs = nltk.bigrams(brown.tagged_words(tagset='universal'))
noun_preceding_tags = [preceding_word[1] for (preceding_word, word) in word_tag_pairs if word[1] == 'NOUN']

fdist = nltk.FreqDist(noun_preceding_tags)
fdist.tabulate()
# Out:
#   DET   ADJ  NOUN   ADP     .  VERB  CONJ   NUM   ADV   PRT  PRON     X
# 85845 54653 41309 37418 20084 17851  9294  5668  1851  1068   440    77

# %% [markdown]
# ### Exercise 5
#
# Write a function `ambiguous(tagged_text)` that returns the number of ambiguous word types as well as the number of all word types in a tagged text. A word type is ambiguous if it is tagged with at least two different tags. Use the function to print both values as well as the percentage of ambiguous word types for the Brown Corpus both for the original and the universal tagset.

# %%
# A tagged_text consists of words with its assigned word types (=tags)
def ambiguous(tagged_text: list[tuple[str, str]]):
    tagged_words_cfd = nltk.ConditionalFreqDist(tagged_text)
    ambiguous_words = [word for word in tagged_words_cfd if len(tagged_words_cfd[word]) > 1]
    
    return len(ambiguous_words), len(tagged_words_cfd)

# %%
tagged_words = brown.tagged_words()
tagged_words_universal = brown.tagged_words(tagset='universal')

ambiguous_regular = ambiguous(tagged_words)
ambiguous_universal = ambiguous(tagged_words_universal)

# %%
print("name: ambiguous, all, ratio", end="\n===\n")
print("Brown regular tagset: %d, %d, " % ambiguous_regular, end="") 
print("{:.2%}".format(ambiguous_regular[0]/ambiguous_regular[1]))
print("Brown universal tagset: %d, %d, " % ambiguous_universal, end="")
print("{:.2%}".format(ambiguous_universal[0]/ambiguous_universal[1]))
# Out:
# name: ambiguous, all, ratio
# ===
# Brown regular tagset: 8729, 56057, 15.57%
# Brown universal tagset: 3596, 56057, 6.41%

# %% [markdown]
# ### Exercise 6
#
# Write code to search the Brown Corpus to answer the following questions:
#
# a) produce an alphabetically sorted list of the distinct words tagged as `MD`
# b) identify words that can be plural nouns or third person singular verbs
# c) print an alphabetically sorted list of distinct three-word prepositional phrases of the form `IN+AT+NN`, separated by semicolons

# %%
# Solution to a)
print(sorted(set([word.lower() for (word, tag) in tagged_words if tag == 'MD'])))
# Out:
# ["c'n", 'can', 'colde', 'could', 'dare', 'kin', 'maht', 'mai', 'may', 'maye', 'mayst', 'might', 'must', 'need', 'ought', 'shall', 'should', 'shuld', 'shulde', 'wil', 'will', 'wilt', 'wod', 'wold', 'wolde', 'would']

# %%
# Solution to b)
nltk.help.upenn_tagset('NNS')
nltk.help.upenn_tagset('VBZ')
# Out:
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...

# %%
tagged_words_norm = [word.lower() for (word, tag) in tagged_words]
tagged_words_cfd = nltk.ConditionalFreqDist(tagged_words)

print(set([word for word in set(tagged_words_norm) if 'NNS' in tagged_words_cfd[word] and 'VBZ' in tagged_words_cfd[word]]))
# Out:
# {'reports', 'compresses', 'traces', 'experiences', 'shares', 'guides', 'cracks', 'honors', 'challenges', 'crops', 'thrusts', 'mounts', 'starts', 'flies', 'transfers', 'names', 'attacks', 'answers', 'bullies', 'parallels', 'dogs', 'points', 'passes', 'bridges', 'shocks', 'exhibits', 'stands', 'excuses', 'traps', 'wants', 'contracts', 'presses', 'hides', 'snatches', 'kids', 'deals', 'clouds', 'figures', 'springs', 'wishes', 'lies', 'pushes', 'drains', 'costs', 'caps', 'lapses', 'bottles', 'blows', 'imports', 'respects', 'champions', 'shows', 'records', 'clucks', 'supplies', 'dies', 'conducts', 'banks', 'checks', 'sports', 'houses', 'stops', 'features', 'escapes', 'strikes', 'acts', 'deserts', 'practices', 'jokes', 'stains', 'guarantees', 'sums', 'commands', 'reserves', 'photographs', 'bristles', 'dislikes', 'conflicts', 'slips', 'smiles', 'subjects', 'influences', 'sets', 'embraces', 'concerns', 'laps', 'surveys', 'captures', 'concentrates', 'shifts', 'shakes', 'drinks', 'leases', 'likes', 'flags', 'remarks', 'notes', 'studies', 'hates', 'plans', 'lines', 'sanctions', 'increases', 'stretches', 'covers', 'ranks', 'makes', 'extracts', 'sponsors', 'delays', 'forces', 'peers', 'hits', 'dances', 'treats', 'holds', 'winds', 'scans', 'leaves', 'limits', 'factors', 'signals', 'bends', 'colors', 'falls', 'equals', 'lands', 'rolls', 'declines', 'lives', 'permits', 'meets', 'trains', 'leaps', 'spreads', 'ranches', 'clutches', 'claps', 'pulls', 'rushes', 'looms', 'struggles', 'sneers', 'votes', 'tops', 'preserves', 'kicks', 'rocks', 'raises', 'swoops', 'rules', 'bows', 'objects', 'affects', 'matters', 'gains', 'bulletins', 'catches', 'watches', 'speeds', 'plays', 'terms', 'faces', 'powers', 'censors', 'sketches', 'markets', 'rings', 'means', 'times', 'decreases', 'touches', 'bubbles', 'wonders', 'returns', 'labels', 'graduates', 'protests', 'blots', 'attributes', 'results', 'displays', 'bites', 'contacts', 'snowballs', 'dreams', 'hauls', 'changes', 'ties', 'demands', 'towers', 'replies', 'feeds', 'tries', 'belts', 'arches', 'skins', 'mentions', 'clicks', 'bats', 'scales', 'looks', 'wins', 'uses', 'searches', 'initiates', 'encounters', 'sheds', 'accounts', 'designs', 'picks', 'functions', 'centers', 'reviews', 'blueprints', 'amounts', 'ends', 'flourishes', 'exercises', 'marks', 'releases', 'harbors', 'issues', 'coordinates', 'advances', 'bores', 'butts', 'reaches', 'totals', 'talks', 'rates', 'estimates', 'shapes', 'backs', 'cries', 'lays', 'lifts', 'doubles', 'numbers', 'shouts', 'labors', 'supports', 'cuts', 'rests', 'regrets', 'finishes', 'upsets', 'splashes', 'sounds', 'loves', 'turns', 'pauses', 'walks', 'bars', 'orders', 'bangs', 'flows', 'stays', 'rains', 'comments', 'drops', 'reasons', 'haunts', 'paints', 'toys', 'counts', 'trades', 'marches', 'registers', 'spies', 'assaults', 'drives', 'aids', 'blankets', 'vows', 'levels', 'casts', 'crosses', 'desires', 'beats', 'decrees', 'runs', 'purges', 'damages', 'tastes', 'requests', 'needs', 'approaches', 'promises', 'petitions', 'splits', 'remains', 'piles', 'stems', 'calls', 'associates', 'claims', 'rises', 'moves', 'works', 'lags', 'charges', 'steps', 'knuckles', 'quarrels', 'stakes', 'kills', 'yields', 'ranges', 'senses', 'tortures', 'bargains', 'dishes', 'spans', 'lists', 'phones', 'dwarfs', 'plots', 'rides', 'weights', 'hunts', 'seals', 'visits', 'courts', 'worries', 'proceeds', 'keeps', 'drifts', 'services', 'tests', 'fractures', 'pictures', 'benefits', 'kisses', 'deeds', 'regards', 'dictates', 'knocks', 'plunges', 'fields', 'snows', 'helps', 'bugs', 'burns', 'glories', 'borders', 'places', 'misses', 'breaks', 'sticks', 'interests', 'fights', 'appeals', 'matches', 'attempts', 'jumps', 'wrenches', 'outlines', 'views', 'fears', 'rebels', 'causes', 'suits', 'moderates', 'dates', 'addresses', 'fashions', 'mistakes', 'urges', 'measures', 'trusts', 'fits', 'gestures', 'sparks', 'parades', 'bases', 'forms', 'cycles', 'says', 'handles', 'cares', 'merits', 'switches', 'lights', 'fishes', 'tires ...

# %%
# Solution to c)
three_word_phrases = set([(w1, w2, w3) for sent in brown.tagged_sents() for (w1, t1), (w2, t2), (w3, t3) in nltk.trigrams(sent) if t1 == 'IN' and t2 == 'AT' and t3 == 'NN'])

# %%
for phrase in sorted(three_word_phrases):
    print("%s %s %s" % phrase, end=";")
# Out:
# 'bout the saddle;'ceptin' the light;About the murder;Above the tongue;Across the bay;Across the bridge;Across the front;Across the road;Across the street;Across the table;Across the way;After a conversation;After a day;After a dinner;After a flood;After a minute;After a moment;After a pause;After a reception;After a roundup;After a sort;After a supper;After a time;After a while;After a year;After an earthquake;After every money;After every session;After the collapse;After the demise;After the diagnosing;After the game;After the meal;After the meeting;After the pegboard;After the soil;After the spate;After the storm;After the war;Against the ruin;Along the way;Amid a shortage;Amid the crackle;Among the policy;Around the billiard;Around the table;As a result;At a ceremony;At a minimum;At a nod;At a party;At a rate;At a reception;At a siding;At no time;At the Seashore;At the adoption;At the age;At the base;At the beginning;At the bottom;At the close;At the conclusion;At the door;At the doorway;At the edge;At the end;At the entrance;At the gate;At the head;At the heart;At the height;At the inn;At the inquest;At the insistence;At the landing;At the meeting;At the moment;At the nadir;At the opening;At the order;At the outset;At the peak;At the point;At the rate;At the rear;At the risk;At the scene;At the sight;At the start;At the time;At the top;At the trial;At the workshop;Below the fort;Beneath the dome;Besides the bundle;Besides the lack;Besides the presence;Between the telephone;Beyond the forest;Beyond the stockade;By a combination;By an effort;By the age;By the death;By the end;By the look;By the middle;By the time;By the use;By the way;Concerning the sentence;Considering the nature;Considering the state;Despite an ambiguity;Despite the clarity;Despite the excitement;Despite the fact;Despite the hopelessness;Despite the lip;Despite the opposition;Despite the recession;Despite the rejection;Down the boulevard;Down the tree;During a round;During a sojourn;During the assignment;During the biennium;During the course;During the decade;During the discharge;During the election;During the excitement;During the making;During the month;During the morning;During the night;During the pension;During the period;During the quarrel;During the rest;During the return;During the summer;During the trial;During the trip;During the war;During the year;Following the term;For a chemical;For a man;For a minute;For a moment;For a number;For a resort;For a steak;For a time;For a while;For a year;For an anthropologist;For an antique;For an engine;For an example;For an experiment;For an instant;For every person;For the albumin;For the army;For the boy;For the case;For the convenience;For the dignity;For the figure;For the future;For the government;For the industry;For the interpretation;For the low-temperature;For the maintenance;For the marksman;For the moment;For the occasion;For the present;For the president;For the prevention;For the purpose;For the reason;For the remainder;For the school;For the treatment;For the use;For the vertex;For the year;From a man;From a pen;From an exercise;From the back;From the beginning;From the brightness;From the coil;From the collection;From the crowd;From the curio;From the equilibrium;From the evidence;From the luggage;From the man;From the moment;From the night;From the outset;From the outside;From the point;From the standpoint;From the time;From the town;From the volume;From the way;From the wealth;In a B;In a book;In a camp;In a climate;In a controversy;In a course;In a flash;In a fraction;In a frenzy;In a kind;In a letter;In a matter;In a minute;In a neighborhood;In a sample;In a saucepan;In a sense;In a series;In a set;In a society;In a story;In a stream;In a succession;In a symposium;In a time;In a total;In a tour;In a voice;In a waterfall;In a way;In a week;In a word;In a year;In an FELA;In an age;In an attempt;In an effort;In an emergency;In an hour;In an instant;In every aspect;In every war;In no way;In the  ...

# %% [markdown]
# ### Exercise 7
#
# Write a function `prec_adv(word, text)` that returns an alphabetically sorted list of distinct adverbs that precede `word` in `text`. Use this function to find out which adverbs precede the words "love", "like", and "prefer" in the Brown corpus.

# %%
def prec_adv(word, text):
    if hasattr(text, "tagged_words"):
        tagged_text = text.tagged_words(tagset='universal')
    else:
        # Assuming that text is an untagged string
        text = nltk.word_tokenize(text)
        tagged_text = nltk.pos_tag(text, tagset='universal')

    word_tag_pairs = nltk.bigrams(tagged_text)
    preceding_adverbs = set([preceding[0] for preceding, succeeding in word_tag_pairs if succeeding[0] == word and preceding[1] == 'ADV'])
    
    return list(sorted(preceding_adverbs))
    
t = "They had been doing this extraordinarily fast."
w = "fast"

print("Preceding 'love': ", prec_adv("love", brown))
print("Preceding 'like': ", prec_adv("like", brown))
print("Preceding 'prefer': ", prec_adv("prefer", brown))
# Out:
# Preceding 'love':  ['always', 'dearly', 'just', 'not']
# Preceding 'like':  ['How', 'Jist', 'Just', 'Kinda', 'More', 'Not', 'abreast', 'almost', 'alone', 'always', 'around', 'by', 'close', 'deceptively', 'even', 'exactly', 'gloriously', 'here', 'increasingly', 'jist', 'just', 'less', 'more', 'much', 'not', 'often', 'particularly', 'quick', 'quite', 'rather', 'remarkably', 'roughly', 'simply', 'so', 'somewhat', 'sure', 'there', 'together', 'wildly', 'yet']
# Preceding 'prefer':  ['generally', 'much', 'not', 'spontaneously']
